# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("D:/ML_Project/KNN/Salary_Data.csv")
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
df.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.head
# Out:
# <bound method NDFrame.head of     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# ...

# %%
x=df.iloc[:,:-1]
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
x.ndim
# Out:
# 2

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
y.ndim
# Out:
# 1

# %%
plt.scatter(x, y, color='blue')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs Years of Experience Scatter Plot')
plt.show()

# %%
#Training and Testing Data 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)
x_train
# Out:
#     YearsExperience
# 14              4.5
# 24              8.7
# 11              4.0
# 27              9.6
# 16              5.1
# 28             10.3
# 15              4.9
# 12              4.0
# 0               1.1
# 4               2.2
# 20              6.8
# 23              8.2
# 10              3.9
# 17              5.3
# 7               3.2
# 5               2.9
# 9               3.7
# 19              6.0
# 21              7.1
# 22              7.9
# 26              9.5

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 81537.66752248, 127680.28405684,  42416.75350422,  54453.95781753,
#         35395.05098812,  52447.75709865, 112633.7786652 ,  63481.86105251,
#         37401.25170701])

# %%
x_test
# Out:
#     YearsExperience
# 18              5.9
# 29             10.5
# 3               2.0
# 8               3.2
# 1               1.3
# 6               3.0
# 25              9.0
# 13              4.1
# 2               1.5

# %%
y_train
# Out:
# 14     61111.0
# 24    109431.0
# 11     55794.0
# 27    112635.0
# 16     66029.0
# 28    122391.0
# 15     67938.0
# 12     56957.0
# 0      39343.0
# 4      39891.0
# 20     91738.0
# 23    113812.0
# 10     63218.0
# 17     83088.0
# 7      54445.0
# 5      56642.0
# 9      57189.0
# 19     93940.0
# 21     98273.0
# 22    101302.0
# 26    116969.0
# Name: Salary, dtype: float64

# %%
y_test
# Out:
# 18     81363.0
# 29    121872.0
# 3      43525.0
# 8      64445.0
# 1      46205.0
# 6      60150.0
# 25    105582.0
# 13     57081.0
# 2      37731.0
# Name: Salary, dtype: float64

# %%
print(model.predict([[6.8]]))
# Out:
# [90565.57075747]
# c:\Users\richi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Data frame
df1=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
df1
# Out:
#       Actual      Predicted
# 18   81363.0   81537.667522
# 29  121872.0  127680.284057
# 3    43525.0   42416.753504
# 8    64445.0   54453.957818
# 1    46205.0   35395.050988
# 6    60150.0   52447.757099
# 25  105582.0  112633.778665
# 13   57081.0   63481.861053
# 2    37731.0   37401.251707

# %%
plt.scatter(x_train, y_train, color='blue')
plt.plot(x_test, y_pred, color='red')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
#y= mx+c
print(model.coef_)  #m
# Out:
# [10031.00359443]

# %%
#constant
print(model.intercept_)  #c
# Out:
# 22354.74631536584

# %%
#Model Performance
from sklearn import metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
mae

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape=mean_absolute_percentage_error(y_test,y_pred)
mape
