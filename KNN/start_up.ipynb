# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
df=pd.read_csv('https://raw.githubusercontent.com/arib168/data/main/50_Startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
print(df.shape)
# Out:
# (50, 5)

# %%
df.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
df.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
plt.figure(figsize=(8,6))
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation heatmap (numeric variables)')
plt.show()

# %%
df['State'].unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
df['State'].value_counts()
# Out:
# State
# New York      17
# California    17
# Florida       16
# Name: count, dtype: int64

# %%
plt.bar(df['State'].value_counts().index, df['State'].value_counts().values)
plt.xlabel('State')
plt.ylabel('Count')
plt.show()

# %%
plt.pie(df['State'].value_counts(),autopct='%1.1f%%',labels=df['State'].value_counts().index)
plt.show()

# %%
# count and inspect object dtype columns in the existing dataframe `df`
obj_cols = df.select_dtypes(include=['object']).columns
print("Object dtype columns:", list(obj_cols))
print("Count:", len(obj_cols))

for col in obj_cols:
    print(f"\nColumn: {col}")
    print("Non-null count:", df[col].notna().sum())
    print("Unique values:", df[col].nunique())
    print("Value counts:")
    print(df[col].value_counts())
# Out:
# Object dtype columns: ['State']
# Count: 1
#
# Column: State
# Non-null count: 50
# Unique values: 3
# Value counts:
# State
# New York      17
# California    17
# Florida       16
# Name: count, dtype: int64

# %%
#separate input and output
x=df.iloc[:,:-1] #input , .values to convet into array
y=df.iloc[:,-1] #output
x
# Out:
#     R&D Spend  Administration  Marketing Spend       State
# 0   165349.20       136897.80        471784.10    New York
# 1   162597.70       151377.59        443898.53  California
# 2   153441.51       101145.55        407934.54     Florida
# 3   144372.41       118671.85        383199.62    New York
# 4   142107.34        91391.77        366168.42     Florida
# 5   131876.90        99814.71        362861.36    New York
# 6   134615.46       147198.87        127716.82  California
# 7   130298.13       145530.06        323876.68     Florida
# 8   120542.52       148718.95        311613.29    New York
# 9   123334.88       108679.17        304981.62  California
# 10  101913.08       110594.11        229160.95     Florida
# 11  100671.96        91790.61        249744.55  California
# 12   93863.75       127320.38        249839.44     Florida
# 13   91992.39       135495.07        252664.93  California
# 14  119943.24       156547.42        256512.92     Florida
# ...

# %%
# visualize the dependent variable (Profit)
plt.figure(figsize=(12,4))
sns.set_style('whitegrid')

plt.subplot(1,3,1)
sns.histplot(df['Profit'], kde=True, color='skyblue', bins=15)
plt.xlabel('Profit')
plt.title('Profit Distribution')

plt.tight_layout()
plt.show()

# %%
sns.regplot(x='R&D Spend', y='Profit', data=df, scatter_kws={'color':'blue'}, line_kws={'color':'red'})
# Out:
# <Axes: xlabel='R&D Spend', ylabel='Profit'>

# %%
sns.regplot(x=df['Administration'], y=df['Profit'], scatter_kws={'color':'green'}, line_kws={'color':'orange'})
# Out:
# <Axes: xlabel='Administration', ylabel='Profit'>

# %%
sns.regplot(x='Marketing Spend', y='Profit', data=df, color='green', marker='+')
plt.show()

# %%
import sklearn

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
one = make_column_transformer(
	(OneHotEncoder(handle_unknown='ignore'), ['State']),
	remainder='passthrough'
)
x = one.fit_transform(x)
x
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.6534920e+05,
#         1.3689780e+05, 4.7178410e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.6259770e+05,
#         1.5137759e+05, 4.4389853e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.5344151e+05,
#         1.0114555e+05, 4.0793454e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.4437241e+05,
#         1.1867185e+05, 3.8319962e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.4210734e+05,
#         9.1391770e+04, 3.6616842e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.3187690e+05,
#         9.9814710e+04, 3.6286136e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.3461546e+05,
#         1.4719887e+05, 1.2771682e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.3029813e+05,
#         1.4553006e+05, 3.2387668e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.2054252e+05,
#         1.4871895e+05, 3.1161329e+05],
# ...

# %%
plt.scatter(df['R&D Spend'],df['Profit'])
plt.xlabel('R&D Spend')
plt.ylabel('Profit')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([126187.39411505,  85788.82259512,  99777.02815177,  45706.12238327,
#        127062.20722772,  51891.83884456, 109114.62977494, 100600.61123702,
#         97953.99874714, 111730.57706807, 128818.49200668, 174195.35772632,
#         93736.28538438, 148381.0409716 , 172313.87139389])

# %%
x.shape
# Out:
# (50, 6)

# %%
y_test
# Out:
# 13    134307.35
# 39     81005.76
# 30     99937.59
# 45     64926.08
# 17    125370.37
# 48     35673.41
# 26    105733.54
# 25    107404.34
# 32     97427.84
# 19    122776.86
# 12    141585.52
# 4     166187.94
# 37     89949.14
# 8     152211.77
# 3     182901.99
# Name: Profit, dtype: float64

# %%
df1 = pd.DataFrame({
    'Actual_value': y_test,
    'Predicted_value': y_pred
})
df1['Absolute_Error'] = (df1['Actual_value'] - df1['Predicted_value']).abs()
df1['Absolute_Percent_Error'] = 100 * df1['Absolute_Error'] / df1['Actual_value']

df1
# Out:
#     Actual_value  Predicted_value  Absolute_Error  Absolute_Percent_Error
# 13     134307.35    126187.394115     8119.955885                6.045802
# 39      81005.76     85788.822595     4783.062595                5.904596
# 30      99937.59     99777.028152      160.561848                0.160662
# 45      64926.08     45706.122383    19219.957617               29.602831
# 17     125370.37    127062.207228     1691.837228                1.349471
# 48      35673.41     51891.838845    16218.428845               45.463635
# 26     105733.54    109114.629775     3381.089775                3.197746
# 25     107404.34    100600.611237     6803.728763                6.334687
# 32      97427.84     97953.998747      526.158747                0.540050
# 19     122776.86    111730.577068    11046.282932                8.997040
# 12     141585.52    128818.492007    12767.027993                9.017185
# 4      166187.94    174195.357726     8007.417726                4.818291
# ...

# %%
print(model.coef_)
# Out:
# [ 2.59028652e+02  7.17099427e+02 -9.76128080e+02  8.04937292e-01
#  -9.12577104e-02  2.80672826e-02]

# %%
print(model.intercept_)
# Out:
# 57153.61206240456

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score
mape=mean_absolute_percentage_error(y_test,y_pred)
mape
# Out:
# 0.08929865344170522

# %%
score = r2_score(y_test, y_pred)
score
# Out:
# 0.9397108063355801
