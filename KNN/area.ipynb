# %%
import matplotlib.pyplot as plt

areas = [2600, 3000, 3200, 3600, 4000]
prices = [5500000, 6100000, 6200000, 6800000, 7100000]

plt.scatter(areas, prices, color='blue')
plt.xlabel('Area (sqft)')
plt.ylabel('Price')
plt.title('Area vs Price Scatter Plot')
plt.show()

# %%
import numpy as np
y_pred = m * np.array(areas) + c

plt.scatter(areas, prices, color='blue', label='Data')
plt.plot(x_fit, y_fit, color='red', label=f'Fit: y = {m:.6f}x + {c:.6f}')
plt.scatter(areas, y_pred, color='orange', marker='x', label='Predicted (m*x+c)')
plt.xlabel('Area (sqft)')
plt.ylabel('Price')
plt.title('Area vs Price with Linear Fit')
plt.legend()
plt.show()
