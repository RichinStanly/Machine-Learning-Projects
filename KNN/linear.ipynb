# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("simplelinearregression.csv")
df
# Out:
#    Age  Premium
# 0   18    10000
# 1   22    15000
# 2   23    18000
# 3   26    21000
# 4   28    24000
# 5   31    26500
# 6   33    27000

# %%
df.dtypes
# Out:
# Age        int64
# Premium    int64
# dtype: object

# %%
df.isna().sum()
# Out:
# Age        0
# Premium    0
# dtype: int64

# %%
df.head
# Out:
# <bound method NDFrame.head of    Age  Premium
# 0   18    10000
# 1   22    15000
# 2   23    18000
# 3   26    21000
# 4   28    24000
# 5   31    26500
# 6   33    27000>

# %%
df.tail
# Out:
# <bound method NDFrame.tail of    Age  Premium
# 0   18    10000
# 1   22    15000
# 2   23    18000
# 3   26    21000
# 4   28    24000
# 5   31    26500
# 6   33    27000>

# %%
x=df.iloc[:,:-1]
x
# Out:
#    Age
# 0   18
# 1   22
# 2   23
# 3   26
# 4   28
# 5   31
# 6   33

# %%
x.ndim
# Out:
# 2

# %%
y=df.iloc[:,-1]
y
# Out:
# 0    10000
# 1    15000
# 2    18000
# 3    21000
# 4    24000
# 5    26500
# 6    27000
# Name: Premium, dtype: int64

# %%
y.ndim
# Out:
# 1

# %%
plt.scatter(x, y, color='blue')
plt.xlabel('Age')
plt.ylabel('premium')
plt.title('premium vs Age Scatter Plot')
plt.show()

# %%
#Training and Testing Data 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)
x_train
# Out:
#    Age
# 6   33
# 3   26
# 5   31
# 2   23

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([22888.44621514, 13426.29482072, 17211.15537849])

# %%
x_test
# Out:
#    Age
# 4   28
# 0   18
# 1   22

# %%
y_train
# Out:
# 6    27000
# 3    21000
# 5    26500
# 2    18000
# Name: Premium, dtype: int64

# %%
y_test
# Out:
# 4    24000
# 0    10000
# 1    15000
# Name: Premium, dtype: int64

# %%
print(model.predict([[6.8]]))
# Out:
# [2828.68525896]
# c:\Users\richi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Data frame
df1=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
df1
# Out:
#    Actual     Predicted
# 4   24000  22888.446215
# 0   10000  13426.294821
# 1   15000  17211.155378

# %%
plt.scatter(x_train, y_train, color='blue')
plt.plot(x_test, y_pred, color='red')
plt.xlabel('Age')
plt.ylabel('premium')
# Out:
# Text(0, 0.5, 'premium')

# %%
#y= mx+c
print(model.coef_)  #m
# Out:
# [946.21513944]

# %%
#constant
print(model.intercept_)  #c
# Out:
# -3605.5776892430185

# %%
#Model Performance
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 2249.667994687917

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape=mean_absolute_percentage_error(y_test,y_pred)
mape
# Out:
# 0.1787848605577691

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 5954752.040972908
